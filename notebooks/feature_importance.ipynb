# %%
import xgboost as xg
import matplotlib.pyplot as plt

# %%
model = xg.Booster()
model.load_model('../scripts/models/final_model.json')

# %%
feature_importances = model.get_score(importance_type='gain')
print(feature_importances)

features = list(feature_importances.keys())
importances = list(feature_importances.values())
# Out:
# {'site_id': 7.7122273445129395, 'visitor_location_country_id': 7.402902126312256, 'visitor_hist_starrating': 7.428715229034424, 'visitor_hist_adr_usd': 8.224745750427246, 'prop_country_id': 10.567734718322754, 'prop_brand_bool': 11.610392570495605, 'prop_location_score2': 37.630035400390625, 'srch_destination_id': 6.895325660705566, 'srch_booking_window': 7.188523769378662, 'srch_saturday_night_bool': 5.729381561279297, 'srch_query_affinity_score': 8.031628608703613, 'random_bool': 21.512041091918945, 'has_hist_starrating': 5.353610992431641, 'has_hist_adr_usd': 1.4121298789978027, 'score1d2': 22.757307052612305, 'normalized_prop_starrating': 13.39184856414795, 'normalized_score1d2': 9.906539916992188, 'normalized_prop_review_score': 9.14677619934082, 'hotel_quality': 8.859292030334473, 'normalized_hotel_quality': 12.770073890686035, 'price_per_person': 7.832462787628174, 'avg_price_per_day': 8.923151016235352, 'ump': 15.888801574707031, 'price_diff': 9.55831241607666, 'starrating_diff': 8.39944076538086, 'total_price': 10.20551586151123, 'promotion_count': 8.919548988342285, 'promotion_any': 9.30925178527832, 'price_rank': 19.948759078979492, 'star_rank': 15.447859764099121}

# %%
plt.figure(figsize=(10, 6))
plt.bar(features, importances)
plt.title('Feature Importances')
plt.xlabel('Features')
plt.ylabel('Importance Score (Gain)')
plt.xticks(rotation=90)
plt.show()
