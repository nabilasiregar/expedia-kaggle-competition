# %%
import xgboost as xg
import matplotlib.pyplot as plt

# %%
model = xg.Booster()
model.load_model('model.json')

# %%
feature_importances = model.get_score(importance_type='gain')
print(feature_importances)

features = list(feature_importances.keys())
importances = list(feature_importances.values())
# Out:
# {'site_id': 0.1177351251244545, 'visitor_location_country_id': 0.1286221444606781, 'visitor_hist_starrating': 0.2279772013425827, 'visitor_hist_adr_usd': 0.17965075373649597, 'prop_country_id': 0.28440144658088684, 'prop_starrating': 0.15428687632083893, 'prop_review_score': 0.1998625248670578, 'prop_brand_bool': 0.14468231797218323, 'prop_location_score1': 0.2133762389421463, 'prop_location_score2': 0.24411331117153168, 'prop_log_historical_price': 0.1852567344903946, 'position': 0.13271507620811462, 'price_usd': 0.15142764151096344, 'promotion_flag': 0.3383036255836487, 'srch_destination_id': 0.17227421700954437, 'srch_length_of_stay': 0.13523487746715546, 'srch_booking_window': 0.1893463432788849, 'srch_adults_count': 0.13272491097450256, 'srch_children_count': 0.16870173811912537, 'srch_room_count': 1.7452924251556396, 'srch_saturday_night_bool': 0.16625019907951355, 'srch_query_affinity_score': 0.2814381420612335, 'orig_destination_distance': 0.2836551368236542, 'random_bool': 0.05174366012215614, 'comp2_rate': 0.11451119184494019, 'comp2_inv': 0.16530679166316986, 'comp2_rate_percent_diff': 0.34202471375465393, 'comp3_rate': 0.05679701268672943, 'comp3_inv': 0.22234170138835907, 'comp3_rate_percent_diff': 0.29031604528427124, 'comp4_rate': 0.7627054452896118, 'comp4_inv': 0.1338043063879013, 'comp4_rate_percent_diff': 0.3023015558719635, 'comp5_rate': 0.07911502569913864, 'comp5_inv': 0.3284476399421692, 'comp5_rate_percent_diff': 0.10748440027236938, 'comp6_inv': 0.05437833070755005, 'comp7_inv': 0.016688242554664612, 'comp8_rate': 0.37682536244392395, 'comp8_inv': 0.32491230964660645, 'comp8_rate_percent_diff': 0.2020951509475708}

# %%
plt.figure(figsize=(10, 6))
plt.bar(features, importances)
plt.title('Feature Importances')
plt.xlabel('Features')
plt.ylabel('Importance Score (Gain)')
plt.xticks(rotation=90)
plt.show()
